# %% [markdown]
# # Cohort Analysis on E-Commerce Data
# Secara garis besar, terdapat 3 tahapan yang perlu kita lakukan untuk melakukan cohort analysis, diantaranya:
# 1. Mempersiapkan kolom-kolom yang dibutuhkan
# 2. Membuat tabel retensi
# 3. Membuat visualisasi dalam bentuk heatmap
#
# Ada 3 kolom yang perlu dibuat agar kita dapat melakukan cohort analysis, yaitu:
# 1. Invoice periode - waktu (hari, bulan, atau tahun) terjadinya sebuah transaksi
# 2. Cohort group - cohorts (kelompok pelanggan) berupa waktu (hari, bulan, atau tahun) kapan pelanggan melakukan transaksi pertamanya
# 3. Cohort period - periode waktu (hari, bulan, atau tahun) yang digunakan untuk mencatat perkembangan perilaku pelanggan setiap waktunya

# %% [markdown]
# #### Data preparation before doing the analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
# read dataset
df = pd.read_csv('../datasets/cleaned_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  InvoiceNo StockCode                          Description  \
# 0           0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1           1     536365     71053                  WHITE METAL LANTERN
# 2           2     536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3           3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4           4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
#
#    Quantity          InvoiceDate  UnitPrice  CustomerID         Country
# 0         6  2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1         6  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2         8  2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3         6  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4         6  2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# delete 'Unnamed: 0' column
del df['Unnamed: 0']

# %%
# re-check the updated dataframe
df.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4  2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# get data dimension
print('Number of columns:', df.shape[0])
print('Number of rows:', df.shape[1])
# Out:
# Number of columns: 392732
# Number of rows: 8

# %%
# change the format of 'InvoiceDate' to datetime
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# %% [markdown]
# ## 1. Prepare some columns needed for analysis
# Ada 3 kolom yang perlu dibuat agar kita dapat melakukan cohort analysis, yaitu:
# 1. Invoice periode - waktu (hari, bulan, atau tahun) terjadinya sebuah transaksi
# 2. Cohort group - cohorts (kelompok pelanggan) berupa waktu (hari, bulan, atau tahun) kapan pelanggan melakukan transaksi pertamanya
# 3. Cohort period - periode waktu (hari, bulan, atau tahun) yang digunakan untuk mencatat perkembangan perilaku pelanggan setiap waktunya

# %% [markdown]
# #### Task 1. Prepare a column for the invoice period
# Mengingat nantinya kita akan membuat kolom cohorts (kelompok pelanggan), maka kita memerlukan periode invoice yang nilai terkecilnya (bulan paling awal) akan digunakan sebagai nilai cohorts. Oleh sebab itu, kita akan mengambil nilai tanggal tanpa jam, menit, detik untuk mengisi kolom 'InvoicePeriod'.
#
# Mengingat bahwa data ini mencatat transaksi yang terjadi selama 13 bulan, maka nantinya akan terbentuk cohorts (pengelompokan pelanggan) dengan satuan bulan.

# %%
df['InvoicePeriod'] = df['InvoiceDate'].map(lambda d: dt.datetime(d.year, d.month, 1))

# %%
df.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country InvoicePeriod
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom    2010-12-01
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    2010-12-01
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom    2010-12-01
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    2010-12-01
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    2010-12-01

# %% [markdown]
# #### Task 2. Create the cohorts group

# %%
df['Cohorts'] = df.groupby('CustomerID')['InvoicePeriod'].transform('min')

# %%
df.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country InvoicePeriod  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom    2010-12-01
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    2010-12-01
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom    2010-12-01
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    2010-12-01
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    2010-12-01
#
#      Cohorts
# 0 2010-12-01
# 1 2010-12-01
# 2 2010-12-01
# 3 2010-12-01
# 4 2010-12-01

# %% [markdown]
# #### Task 3. Prepare the cohort periods
# Dataset ini merupakan data transaksi yang terjadi selama 13 bulan. Pada analisis kali ini kita akan memantau perubahan perilaku pelanggan setiap bulannya, dari bulan ke-0 (Month 0) hingga terakhir (Month 12). Setiap transaksi/invoice akan memiliki ditandai dengan angka yang menunjukkan apakah transaksi tersebut terjadi pada bulan ke-0 (Dec '10), ke-1 (Jan '11), dst.

# %% [markdown]
# Kita bisa mendapatkan angka tersebut dengan mengambil selisih antara waktu tercatatnya setiap transaksi (InvoicePeriod) dengan waktu tercatatnya transaksi pertama dari pelanggan terkait (Cohorts).

# %%
# fungsi untuk mendapatkan tahun dan bulan transaksi dalam format integer
def get_year_month(df, col):
    year = df[col].dt.year
    month = df[col].dt.month
    return year, month

# %%
# mendapatkan angka tahun dan bulan untuk tanggal invoice dan cohorts
invoice_year, invoice_month = get_year_month(df, 'InvoicePeriod')
cohort_year, cohort_month = get_year_month(df, 'Cohorts')

# %%
# mendapatkan selisih tahun dan bulan antara tanggal invoice dan cohorts
year_diff = invoice_year - cohort_year
month_diff = invoice_month - cohort_month

# %%
# membuat kolom 'CohortPeriod' berdasarkan selisih bulan antara tanggal invoice dan cohorts
df['CohortPeriod'] = year_diff * 12 + month_diff

# %%
df.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country InvoicePeriod  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom    2010-12-01
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    2010-12-01
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom    2010-12-01
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    2010-12-01
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    2010-12-01
#
#      Cohorts  CohortPeriod
# 0 2010-12-01             0
# 1 2010-12-01             0
# 2 2010-12-01             0
# 3 2010-12-01             0
# 4 2010-12-01             0

# %% [markdown]
# Kita telah membuat tiga kolom baru yang diperlukan: InvoicePeriod, Cohorts, dan CohortPeriod.
#
# Langkah selanjutnya yang perlu kita lakukan adalah membuat tabel retensi.

# %% [markdown]
# ## 2. Create the Retention Table

# %%
grouping = df.groupby(['Cohorts', 'CohortPeriod'])

# %%
# get the number of customer for each combination of cohort groups and cohort periods
customer_per_cohort_group_and_period = grouping['CustomerID'].apply(pd.Series.nunique).reset_index()
customer_per_cohort_group_and_period
# Out:
#       Cohorts  CohortPeriod  CustomerID
# 0  2010-12-01             0         885
# 1  2010-12-01             1         324
# 2  2010-12-01             2         286
# 3  2010-12-01             3         340
# 4  2010-12-01             4         321
# ..        ...           ...         ...
# 86 2011-10-01             1          86
# 87 2011-10-01             2          41
# 88 2011-11-01             0         324
# 89 2011-11-01             1          36
# 90 2011-12-01             0          41
#
# [91 rows x 3 columns]

# %%
# create a retention table containing the number of active customer for each cohort periods
customer_number_cohort_table =  customer_per_cohort_group_and_period.pivot(index='Cohorts', columns='CohortPeriod', values='CustomerID')
customer_number_cohort_table
# Out:
# CohortPeriod     0      1      2      3      4      5      6      7      8   \
# Cohorts
# 2010-12-01    885.0  324.0  286.0  340.0  321.0  352.0  321.0  309.0  313.0
# 2011-01-01    417.0   92.0  111.0   96.0  134.0  120.0  103.0  101.0  125.0
# 2011-02-01    380.0   71.0   71.0  108.0  103.0   94.0   96.0  106.0   94.0
# 2011-03-01    452.0   68.0  114.0   90.0  101.0   76.0  121.0  104.0  126.0
# 2011-04-01    300.0   64.0   61.0   63.0   59.0   68.0   65.0   78.0   22.0
# 2011-05-01    284.0   54.0   49.0   49.0   59.0   66.0   75.0   27.0    NaN
# 2011-06-01    242.0   42.0   38.0   64.0   56.0   81.0   23.0    NaN    NaN
# 2011-07-01    188.0   34.0   39.0   42.0   51.0   21.0    NaN    NaN    NaN
# 2011-08-01    169.0   35.0   42.0   41.0   21.0    NaN    NaN    NaN    NaN
# 2011-09-01    299.0   70.0   90.0   34.0    NaN    NaN    NaN    NaN    NaN
# 2011-10-01    358.0   86.0   41.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2011-11-01    324.0   36.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2011-12-01     41.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# CohortPeriod     9      10     11     12
# Cohorts
# 2010-12-01    350.0  331.0  445.0  235.0
# 2011-01-01    136.0  152.0   49.0    NaN
# 2011-02-01    116.0   26.0    NaN    NaN
# 2011-03-01     39.0    NaN    NaN    NaN
# 2011-04-01      NaN    NaN    NaN    NaN
# 2011-05-01      NaN    NaN    NaN    NaN
# 2011-06-01      NaN    NaN    NaN    NaN
# 2011-07-01      NaN    NaN    NaN    NaN
# 2011-08-01      NaN    NaN    NaN    NaN
# 2011-09-01      NaN    NaN    NaN    NaN
# 2011-10-01      NaN    NaN    NaN    NaN
# 2011-11-01      NaN    NaN    NaN    NaN
# 2011-12-01      NaN    NaN    NaN    NaN

# %%
# get the total number of customer in each cohorts
cohort_sizes = customer_number_cohort_table.iloc[:,0]
cohort_sizes
# Out:
# Cohorts
# 2010-12-01    885.0
# 2011-01-01    417.0
# 2011-02-01    380.0
# 2011-03-01    452.0
# 2011-04-01    300.0
# 2011-05-01    284.0
# 2011-06-01    242.0
# 2011-07-01    188.0
# 2011-08-01    169.0
# 2011-09-01    299.0
# 2011-10-01    358.0
# 2011-11-01    324.0
# 2011-12-01     41.0
# Name: 0, dtype: float64

# %% [markdown]
# Based on the output above, we know that the first cohort (Dec '10) has 885 customers, the second cohort (Jan '11) has 417 customers, etc. It means that there were 885 customers making the first transaction on Dec '10 and 417 customers making the first transaction on Jan '11.

# %%
# redefine the retention table with the percentage of customer that still active in each cohort period based on each cohort sizes
retention_table = customer_number_cohort_table.divide(cohort_sizes, axis=0) * 100
retention_table
# Out:
# CohortPeriod     0          1          2          3          4          5   \
# Cohorts
# 2010-12-01    100.0  36.610169  32.316384  38.418079  36.271186  39.774011
# 2011-01-01    100.0  22.062350  26.618705  23.021583  32.134293  28.776978
# 2011-02-01    100.0  18.684211  18.684211  28.421053  27.105263  24.736842
# 2011-03-01    100.0  15.044248  25.221239  19.911504  22.345133  16.814159
# 2011-04-01    100.0  21.333333  20.333333  21.000000  19.666667  22.666667
# 2011-05-01    100.0  19.014085  17.253521  17.253521  20.774648  23.239437
# 2011-06-01    100.0  17.355372  15.702479  26.446281  23.140496  33.471074
# 2011-07-01    100.0  18.085106  20.744681  22.340426  27.127660  11.170213
# 2011-08-01    100.0  20.710059  24.852071  24.260355  12.426036        NaN
# 2011-09-01    100.0  23.411371  30.100334  11.371237        NaN        NaN
# 2011-10-01    100.0  24.022346  11.452514        NaN        NaN        NaN
# 2011-11-01    100.0  11.111111        NaN        NaN        NaN        NaN
# 2011-12-01    100.0        NaN        NaN        NaN        NaN        NaN
#
# CohortPeriod         6          7          8          9          10  \
# Cohorts
# 2010-12-01    36.271186  34.915254  35.367232  39.548023  37.401130
# 2011-01-01    24.700240  24.220624  29.976019  32.613909  36.450839
# 2011-02-01    25.263158  27.894737  24.736842  30.526316   6.842105
# 2011-03-01    26.769912  23.008850  27.876106   8.628319        NaN
# 2011-04-01    21.666667  26.000000   7.333333        NaN        NaN
# 2011-05-01    26.408451   9.507042        NaN        NaN        NaN
# 2011-06-01     9.504132        NaN        NaN        NaN        NaN
# 2011-07-01          NaN        NaN        NaN        NaN        NaN
# 2011-08-01          NaN        NaN        NaN        NaN        NaN
# 2011-09-01          NaN        NaN        NaN        NaN        NaN
# 2011-10-01          NaN        NaN        NaN        NaN        NaN
# 2011-11-01          NaN        NaN        NaN        NaN        NaN
# 2011-12-01          NaN        NaN        NaN        NaN        NaN
#
# CohortPeriod         11         12
# Cohorts
# 2010-12-01    50.282486  26.553672
# 2011-01-01    11.750600        NaN
# 2011-02-01          NaN        NaN
# 2011-03-01          NaN        NaN
# 2011-04-01          NaN        NaN
# 2011-05-01          NaN        NaN
# 2011-06-01          NaN        NaN
# 2011-07-01          NaN        NaN
# 2011-08-01          NaN        NaN
# 2011-09-01          NaN        NaN
# 2011-10-01          NaN        NaN
# 2011-11-01          NaN        NaN
# 2011-12-01          NaN        NaN

# %% [markdown]
# ## 3. Visualize the Retention Table

# %%
cohort_labels = ["Dec '10", "Jan '11", "Feb '11", "Mar '11", "Apr '11", \
                 "May '11", "Jun '11", "Jul '11", "Aug '11", "Sep '11", \
                 "Oct '11", "Nov '11", "Dec '11"]

# %%
# set the width and height of the figure
plt.figure(figsize=(14,7))

# set the title of the heatmap
plt.title('Monthly Retention Rates')

# setup the heatmap
sns.heatmap(data=retention_table, annot=True, fmt='.2f', yticklabels=cohort_labels)

plt.show()
